# %% [markdown]
# Main objective of the analysis that specifies whether your model will be focused on prediction or interpretation.
#
# Brief description of the data set you chose and a summary of its attributes.
#
# Brief summary of data exploration and actions taken for data cleaning and feature engineering.
#
# Summary of training at least three linear regression models which should be variations that cover using a simple linear regression as a baseline, adding polynomial effects, and using a regularization regression. Preferably, all use the same training and test splits, or the same cross-validation method.
#
# A paragraph explaining which of your regressions you recommend as a final model that best fits your needs in terms of accuracy and explainability.
#
# Summary Key Findings and Insights, which walks your reader through the main drivers of your model and insights from your data derived from your linear regression model.
#
# Suggestions for next steps in analyzing this data, which may include suggesting revisiting this model adding specific data features to achieve a better explanation or a better prediction.

# %% [markdown]
# ## Main objetives

# %% [markdown]
# The main objective of this work is to analyze and find patterns in the data that guide us in understanding linear regression models and the creation process.

# %%
# import the libraries
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## About the data

# %% [markdown]
# The CalCOFI data set represents the longest (1949-present) and most complete (more than 50,000 sampling stations) time series of oceanographic and larval fish data in the world. It includes abundance data on the larvae of over 250 species of fish; larval length frequency data and egg abundance data on key commercial species; and oceanographic and plankton data. The physical, chemical, and biological data collected at regular time and space intervals quickly became valuable for documenting climatic cycles in the California Current and a range of biological responses to them.
#
# Reference : https://www.kaggle.com/datasets/sohier/calcofi

# %%
# read the csv file and print the content
bottle = pd.read_csv(r'C:\Users\Rizky_Ade\Documents\File Kuliah\Project\Machine Learning Regression\bottle.csv', low_memory=False, nrows=500)
bottle
# Out:
#      Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 0          1        1  054.0 056.0  19-4903CR-HY-060-0930-05400560-0000A-3
# 1          1        2  054.0 056.0  19-4903CR-HY-060-0930-05400560-0008A-3
# 2          1        3  054.0 056.0  19-4903CR-HY-060-0930-05400560-0010A-7
# 3          1        4  054.0 056.0  19-4903CR-HY-060-0930-05400560-0019A-3
# 4          1        5  054.0 056.0  19-4903CR-HY-060-0930-05400560-0020A-7
# ..       ...      ...          ...                                     ...
# 495       16      496  063.3 058.0  19-4903CR-HY-065-1030-06330580-0700A-7
# 496       16      497  063.3 058.0  19-4903CR-HY-065-1030-06330580-0792A-3
# 497       16      498  063.3 058.0  19-4903CR-HY-065-1030-06330580-0800A-7
# 498       16      499  063.3 058.0  19-4903CR-HY-065-1030-06330580-0900A-7
# 499       16      500  063.3 058.0  19-4903CR-HY-065-1030-06330580-1000A-7
#
#      Depthm  T_degC  Salnty  O2ml_L  STheta  O2Sat  ...  R_PHAEO  R_PRES  \
# 0         0   10.50  33.440     NaN  25.649    NaN  ...      NaN       0
# 1         8   10.46  33.440     NaN  25.656    NaN  ...      NaN       8
# 2        10   10.46  33.437     NaN  25.654    NaN  ...      NaN      10
# 3        19   10.45  33.420     NaN  25.643    NaN  ...      NaN      19
# 4        20   10.45  33.421     NaN  25.643    NaN  ...      NaN      20
# ..      ...     ...     ...     ...     ...    ...  ...      ...     ...
# 495     700    4.90  34.269     NaN  27.114    NaN  ...      NaN     706
# 496     792    4.50  34.310     NaN  27.191    NaN  ...      NaN     798
# 497     800    4.48  34.311     NaN  27.194    NaN  ...      NaN     807
# 498     900    4.21  34.319     NaN  27.230    NaN  ...      NaN     908
# 499    1000    3.95  34.329     NaN  27.265    NaN  ...      NaN    1009
#
#      R_SAMP  DIC1  DIC2  TA1  TA2  pH2  pH1  DIC Quality Comment
# 0       NaN   NaN   NaN  NaN  NaN  NaN  NaN                  NaN
# 1       NaN   NaN   NaN  NaN  NaN  NaN  NaN                  NaN
# 2       NaN   NaN   NaN  NaN  NaN  NaN  NaN                  NaN
# 3       NaN   NaN   NaN  NaN  NaN  NaN  NaN                  NaN
# 4       NaN   NaN   NaN  NaN  NaN  NaN  NaN                  NaN
# ..      ...   ...   ...  ...  ...  ...  ...                  ...
# 495     NaN   NaN   NaN  NaN  NaN  NaN  NaN                  NaN
# 496     NaN   NaN   NaN  NaN  NaN  NaN  NaN                  NaN
# 497     NaN   NaN   NaN  NaN  NaN  NaN  NaN                  NaN
# 498     NaN   NaN   NaN  NaN  NaN  NaN  NaN                  NaN
# 499     NaN   NaN   NaN  NaN  NaN  NaN  NaN                  NaN
#
# [500 rows x 74 columns]

# %% [markdown]
# ## Data cleaning and feature enginering

# %%
bottle.isnull().sum()
# Out:
# Cst_Cnt                  0
# Btl_Cnt                  0
# Sta_ID                   0
# Depth_ID                 0
# Depthm                   0
#                       ...
# TA1                    500
# TA2                    500
# pH2                    500
# pH1                    500
# DIC Quality Comment    500
# Length: 74, dtype: int64

# %%
# drop the columns with more than 50 nan values
bottle.dropna(axis='columns', thresh=50, inplace=True)
bottle.isnull().sum()
# Out:
# Cst_Cnt        0
# Btl_Cnt        0
# Sta_ID         0
# Depth_ID       0
# Depthm         0
# T_degC         1
# Salnty         6
# STheta         7
# RecInd         0
# T_prec         1
# S_prec         6
# P_qual         0
# O_qual         0
# O2Satq         0
# Chlqua         0
# Phaqua         0
# PO4q           0
# SiO3qu         0
# NO2q           0
# NO3q           0
# NH3q           0
# C14A1q         0
# C14A2q         0
# DarkAq         0
# MeanAq         0
# R_Depth        0
# R_TEMP         1
# R_POTEMP       5
# R_SALINITY     6
# R_SIGMA       14
# R_SVA         14
# R_DYNHT        0
# R_PRES         0
# dtype: int64

# %%
# making a correlation matrix to see posible columns to the regression
corr = bottle.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# C:\Users\Rizky_Ade\AppData\Local\Temp\ipykernel_10028\2446080526.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = bottle.corr()
# C:\Users\Rizky_Ade\anaconda3\Lib\site-packages\pandas\io\formats\style.py:3931: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# C:\Users\Rizky_Ade\anaconda3\Lib\site-packages\pandas\io\formats\style.py:3932: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_e1b94_row0_col0, #T_e1b94_row0_col1, #T_e1b94_row1_col0, #T_e1b94_row1_col1, #T_e1b94_row2_col2, #T_e1b94_row2_col23, #T_e1b94_row2_col30, #T_e1b94_row3_col3, #T_e1b94_row3_col24, #T_e1b94_row3_col25, #T_e1b94_row4_col4, #T_e1b94_row4_col26, #T_e1b94_row5_col5, #T_e1b94_row5_col27, #T_e1b94_row6_col6, #T_e1b94_row6_col8, #T_e1b94_row7_col7, #T_e1b94_row8_col6, #T_e1b94_row8_col8, #T_e1b94_row23_col2, #T_e1b94_row23_col23, #T_e1b94_row23_col30, #T_e1b94_row24_col3, #T_e1b94_row24_col24, #T_e1b94_row24_col25, #T_e1b94_row25_col3, #T_e1b94_row25_col24, #T_e1b94_row25_col25, #T_e1b94_row26_col4, #T_e1b94_row26_col26, #T_e1b94_row27_col5, #T_e1b94_row27_col27, #T_e1b94_row28_col28, #T_e1b94_row29_col29, #T_e1b94_row30_col2, #T_e1b94_row30_col23, #T_e1b94_row30_col30 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e1b94_row0_col2, #T_e1b94_row0_col5, #T_e1b94_row0_col23, #T_e1b94_row0_col27, #T_e1b94_row0_col30 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_e1b94_row0_col3, #T_e1b94_row0_col24, #T_e1b94_row0_col25 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_e1b94_row0_col4, #T_e1b94_row0_col26 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_e1b94_row0_col6 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_e1b94_row0_col7, #T_e1b94_row1_col6 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_e1b94_row0_col8 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_e1b94_row0_col9, #T_e1b94_row0_col10, #T_e1b94_row0_col11, #T_e1b94_row0_col12, #T_e1b94_row0_col13, #T_e1b94_row0_col14, #T_e1b94_row0_col15, #T_e1b94_row0_col16, #T_e1b94_row0_col17, #T_e1b94_row0_col18, #T_e1b94_row0_col19, #T_e1b94_row0_col20, #T_e1b94_row0_col21, #T_e1b94_row0_col22, #T_e1b94_row1_col9, #T_e1b94_row1_col10, #T_e1b94_row1_col11, #T_e1b94_row1_col12, #T_e1b94_row1_col13, #T_e1b94_row1_col14, #T_e1b94_row1_col15, #T_e1b94_row1_col16, #T_e1b94_row1_col17, #T_e1b94_row1_col18, #T_e1b94_row1_col19, #T_e1b94_row1_col20, #T_e1b94_row1_col21, #T_e1b94_row1_col22, #T_e1b94_row2_col9, #T_e1b94_row2_col10, #T_e1b94_row2_col11, #T_e1b94_row2_col12, #T_e1b94_row2_col13, #T_e1b94_row2_col14, #T_e1b94_row2_col15, #T_e1b94_row2_col16, #T_e1b94_row2_col17, #T_e1b94_row2_col18, #T_e1b94_row2_col19, #T_e1b94_row2_col20, #T_e1b94_row2_col21, #T_e1b94_row2_col22, #T_e1b94_row3_col9, #T_e1b94_row3_col10, #T_e1b94_row3_col11, #T_e1b94_row3_col12, #T_e1b94_row3_col13, #T_e1b94_row3_col14, #T_e1b94_row3_col15, #T_e1b94_row3_col16, #T_e1b94_row3_col17, #T_e1b94_row3_col18, #T_e1b94_row3_col19, #T_e1b94_row3_col20, #T_e1b94_row3_col21, #T_e1b94_row3_col22, #T_e1b94_row4_col9, #T_e1b94_row4_col10, #T_e1b94_row4_col11, #T_e1b94_row4_col12, #T_e1b94_row4_col13, #T_e1b94_row4_col14, #T_e1b94_row4_col15, #T_e1b94_row4_col16, #T_e1b94_row4_col17, #T_e1b94_row4_col18, #T_e1b94_row4_col19, #T_e1b94_row4_col20, #T_e1b94_row4_col21, #T_e1b94_row4_col22, #T_e1b94_row5_col9, #T_e1b94_row5_col10, #T_e1b94_row5_col11, #T_e1b94_row5_col12, #T_e1b94_row5_col13, #T_e1b94_row5_col14, #T_e1b94_row5_col15, #T_e1b94_row5_col16, #T_e1b94_row5_col17, #T_e1b94_row5_col18, #T_e1b94_row5_col19, #T_e1b94_row5_col20, #T_e1b94_row5_col21, #T_e1b94_row5_col22, #T_e1b94_row6_col9, #T_e1b94_row6_col10, #T_e1b94_row6_col11, #T_e1b94_row6_col12, #T_e1b94_row6_col13, #T_e1b94_row6_col14, #T_e1b94_row6_col15, #T_e1b94_row6_col16, #T_e1b94_row6_col17, #T_e1b94_row6_col18, #T_e1b94_row6_col19, #T_e1b94_row6_col20, #T_e1b94_row6_col21, #T_e1b94_row6_col22, #T_e1b94_row7_col9, #T_e1b94_row7_col10, #T_e1b94_row7_col11, #T_e1b94_row7_col12, #T_e1b94_row7_col13, #T_e1b94_row7_col14, #T_e1b94_row7_col15, #T_e1b94_row7_col16, #T_e1b94_row7_col17, #T_e1b94_row7_col18, #T_e1b94_row7_col19, #T_e1b94_row7_col20, #T_e1b94_row7_col21, #T_e1b94_row7_col22, #T_e1b94_row8_col9, #T_e1b94_row8_col10, #T_e1b94_row8_col11, #T_e1b94_row8_col12, #T_e1b94_row8_col13, #T_e1b94_row8_col14, #T_e1b94_row8_col15, #T_e1b94_row8_col16, #T_e1b94_row8_col17, #T_e1b94_row8_col18, #T_e1b94_row8_col19, #T_e1b94_row8_col20, #T_e1b94_row8_col21, #T_e1b94_row8_col22, #T_e1b94_row9_col0, #T_e1b94_row9_col1, #T_e1b94_row9_col2, #T_e1b94_row9_col3, #T_e1b94_row9_col4, #T_e1b94_row9_col5, #T_e1b94_row9_col6, #T_e1b94_row9_col7, #T_e1b94_row9_col8, #T_e1b94_row9_col9, #T_e1b94_row9_col10, #T_e1b94_row9_col11, #T_e1b94_row9_col12, #T_e1b94_row9_col13, #T_e1b94_row9_col14, #T_e1b94_row9_col15, #T_e1b94_row9_col16, #T_e1b94_row9_col17, #T_e1b94_row9_col18, #T_e1b94_row9_col19, #T_e1b94_row9_col20, #T_e1b94_row9_col21, #T_e1b94_row9_col22, #T_e1b94_row9_col23, #T_e1b94_row9_col24, #T_e1b94_row9_col25, #T_e1b94_row9_col26, #T_e1b94_row9_col27, #T_e1b94_row9_col28, #T_e1b94_row9_col29, #T_e1b94_row9_col30, #T_e1b94_row10_col0, #T_e1b94_row10_col1, #T_e1b94_row10_col2, #T_e1b94_row10_col3, #T_e1b94_row10_col4, #T_e1b94_row10_col5, #T_e1b94_row10_col6, #T_e1b94_row10_col7, #T_e1b94_row10_col8, #T_e1b94_row10_col9, #T_e1b94_row10_col10, #T_e1b94_row10_col11, #T_e1b94_row10_col12, #T_e1b94_row10_col13, #T_e1b94_row10_col14, #T_e1b94_row10_col15, #T_e1b94_row10_col16, #T_e1b94_row10_col17, #T_e1b94_row10_col18, #T_e1b94_row10_col19, #T_e1b94_row10_col20, #T_e1b94_row10_col21, #T_e1b94_row10_col22, #T_e1b94_row10_col23, #T_e1b94_row10_col24, #T_e1b94_row10_col25, #T_e1b94_row10_col26, #T_e1b94_row10_col27, #T_e1b94_row10_col28, #T_e1b94_row10_col29, #T_e1b94_row10_col30, #T_e1b94_row11_col0, #T_e1b94_row11_col1, #T_e1b94 ...

# %%
# Extract 4 columns 'T_degC','Salnty' for better explanation
bottle_df = bottle[['T_degC','Salnty','R_SVA', 'R_Depth']]
bottle_df.columns = ['Temperature', 'Salinity','R_SVA','R_Depth']

# %%
# Saw a correlation matrix to verify the relation between the columns
corr = bottle_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_9e3a3_row0_col0, #T_9e3a3_row1_col1, #T_9e3a3_row2_col2, #T_9e3a3_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9e3a3_row0_col1 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_9e3a3_row0_col2 {
#   background-color: #b70d28;
#   color: #f1f1f1;
# }
# #T_9e3a3_row0_col3, #T_9e3a3_row1_col0, #T_9e3a3_row1_col2, #T_9e3a3_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_9e3a3_row1_col3 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_9e3a3_row2_col0 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_9e3a3_row2_col3 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_9e3a3_row3_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_9e3a3_row3_col1 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_9e3a3_row3_col2 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9e3a3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e3a3_level0_col0" class="col_heading level0 col0" >Temperature</th>
#       <th id="T_9e3a3_level0_col1" class="col_heading level0 col1" >Salinity</th>
#       <th id="T_9e3a3_level0_col2" class="col_heading level0 col2" >R_SVA</th>
#       <th id="T_9e3a3_level0_col3" class="col_heading level0 col3" >R_Depth</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e3a3_level0_row0" class="row_heading level0 row0" >Temperature</th>
#       <td id="T_9e3a3_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_9e3a3_row0_col1" class="data row0 col1" >-0.922900</td>
#       <td id="T_9e3a3_row0_col2" class="data row0 col2" >0.977220</td>
#       <td id="T_9e3a3_row0_col3" class="data row0 col3" >-0.910867</td>
#     </tr>
#     <tr>
#       <th id="T_9e3a3_level0_row1" class="row_heading level0 row1" >Salinity</th>
#       <td id="T_9e3a3_row1_col0" class="data row1 col0" >-0.922900</td>
#       <td id="T_9e3a3_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_9e3a3_row1_col2" class="data row1 col2" >-0.981928</td>
#       <td id="T_9e3a3_row1_col3" class="data row1 col3" >0.835648</td>
#     </tr>
#     <tr>
#       <th id="T_9e3a3_level0_row2" class="row_heading level0 row2" >R_SVA</th>
#       <td id="T_9e3a3_row2_col0" class="data row2 col0" >0.977220</td>
#       <td id="T_9e3a3_row2_col1" class="data row2 col1" >-0.981928</td>
#       <td id="T_9e3a3_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_9e3a3_row2_col3" class="data row2 col3" >-0.867638</td>
#     </tr>
#     <tr>
#       <th id="T_9e3a3_level0_row3" class="row_heading level0 row3" >R_Depth</th>
#       <td id="T_9e3a3_row3_col0" class="data row3 col0" >-0.910867</td>
#       <td id="T_9e3a3_row3_col1" class="data row3 col1" >0.835648</td>
#       <td id="T_9e3a3_row3_col2" class="data row3 col2" >-0.867638</td>
#       <td id="T_9e3a3_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# make a pairplot to see the relationship
sns.pairplot(bottle_df, kind="reg")

# %%
# cleaning the null values
bottle_df.isnull().sum()
# Out:
# Temperature     1
# Salinity        6
# R_SVA          14
# R_Depth         0
# dtype: int64

# %%
bottle_df.fillna(method='ffill', inplace=True)
# Out:
# C:\Users\Rizky_Ade\AppData\Local\Temp\ipykernel_10028\582811302.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bottle_df.fillna(method='ffill', inplace=True)

# %% [markdown]
# ## Linear regression part

# %%
# import the libraries for this section
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler, PolynomialFeatures
from sklearn.model_selection import cross_val_score

# %%
# making the variables X, y and the cv folds
X = bottle_df[['Salinity','R_SVA','R_Depth']]
y = bottle_df[['Temperature']]
folds = 3

# %%
#scale the values
columns = X.columns
X[columns] = MinMaxScaler().fit_transform(X[columns])
# Out:
# C:\Users\Rizky_Ade\AppData\Local\Temp\ipykernel_10028\1818702683.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[columns] = MinMaxScaler().fit_transform(X[columns])

# %%
# making the first lineal regression and output the scores
LR = LinearRegression()
scores = cross_val_score(LR, X, y, cv=folds)

# %%
print(f'The mean of the scores is : {np.mean(scores)}')
# Out:
# The mean of the scores is : 0.9456793446403348

# %% [markdown]
# ## Adding polinomial features

# %% [markdown]
# Polynomial feature is a technique in machine learning that is used to convert the original feature into a polynomial feature. A polynomial feature is a feature that is created by multiplying the original feature by itself multiple times.

# %%
# making a for loop to see the best r2 score
for a in range(1,10):
    poly = PolynomialFeatures(a)
    df_poly = poly.fit_transform(X)
    scores = cross_val_score(LR, df_poly, y, cv=folds, scoring='r2')
    print(f'The mean of the scores is : {np.mean(scores)} for polynomial in : {a}')
# Out:
# The mean of the scores is : 0.9456793446403348 for polynomial in : 1
# The mean of the scores is : 0.8858385416353841 for polynomial in : 2
# The mean of the scores is : -5.618607086264084 for polynomial in : 3
# The mean of the scores is : -19.439634783526845 for polynomial in : 4
# The mean of the scores is : -1268.3387249274165 for polynomial in : 5
# The mean of the scores is : -86665.85072427167 for polynomial in : 6
# The mean of the scores is : -62187365.62384424 for polynomial in : 7
# The mean of the scores is : -28022563554.628067 for polynomial in : 8
# The mean of the scores is : -5379725465633.417 for polynomial in : 9

# %%
## adding ridge
from sklearn.linear_model import Ridge
alphas = [0.001, 0.01, 0.1, 0.9, 1, 10, 50]
for a in alphas:
    LR2 = Ridge(alpha=a)
    scores = cross_val_score(LR2, X, y, cv=folds, scoring='r2')
    np.around(scores, 2)
    print(f'The mean of the scores is : {np.mean(scores)} for alpha in : {a}')
# Out:
# The mean of the scores is : 0.9457464719127295 for alpha in : 0.001
# The mean of the scores is : 0.9463086107205413 for alpha in : 0.01
# The mean of the scores is : 0.9490217032228815 for alpha in : 0.1
# The mean of the scores is : 0.9381691442747885 for alpha in : 0.9
# The mean of the scores is : 0.9369658660408362 for alpha in : 1
# The mean of the scores is : 0.9117518894377808 for alpha in : 10
# The mean of the scores is : 0.7993223506852539 for alpha in : 50

# %%
from sklearn import linear_model

alphas = [0.001, 0.01, 0.1, 0.9, 1, 10, 50]
for a in alphas:
    LR3 = linear_model.Lasso(alpha=a)
    scores = cross_val_score(LR3, X, y, cv=folds, scoring='r2')
    np.around(scores, 2)
    print(f'The mean of the scores is : {np.mean(scores)} for alpha in : {a}')
# Out:
# The mean of the scores is : 0.9455310220718417 for alpha in : 0.001
# The mean of the scores is : 0.9466525757619872 for alpha in : 0.01
# The mean of the scores is : 0.9316203207237496 for alpha in : 0.1
# The mean of the scores is : 0.06824820452618359 for alpha in : 0.9
# The mean of the scores is : -0.012504575901136036 for alpha in : 1
# The mean of the scores is : -0.035163565349731085 for alpha in : 10
# The mean of the scores is : -0.035163565349731085 for alpha in : 50

# %% [markdown]
# ## A paragraph explaining which of your regressions you recommend as a final model that best fits your needs in terms of accuracy and explainability.

# %% [markdown]
# When evaluating the performance of r2 in all the trained models, one of the highest average score in the cross-validation is the linear regression loop with polynomial at degree 10 and alpha at 0.1.
#
# However, we see how in the ridge and lasso regressions it was possible to readjust the model with the added weights to increase performance after adding polynomials, being a good option against overfitting.
#
# With this in mind, based on better explainability at the risk of accuracy, I choose the first simple linear regression model as it should not undergo any transformation.

# %% [markdown]
# ## Summary Key Findings and Insights, which walks your reader through the main drivers of your model and insights from your data derived from your linear regression model.

# %%
# Through the first model, we can observe the coefficients of the regression, which gives
LR = LinearRegression()
LR.fit(X,y)
print(LR.coef_)
print(X.columns)
# Out:
# [[ 3.96428218  9.95769778 -3.22903977]]
# Index(['Salinity', 'R_SVA', 'R_Depth'], dtype='object')

# %% [markdown]
# The explanation here is that each value within the coefficient list means the weight that is added to the final value through a change in input. These weights are directly related to their respective columns since we work with the first linear regression which has not undergone any polynomial transformation.

# %% [markdown]
# ##### Suggestions for next steps in analyzing this data, which may include suggesting revisiting this model adding specific data features to achieve a better explanation or a better prediction

# %% [markdown]
# For the following steps I would try to do more feature engineering to normalize the distribution of the variables, I would also apply more columns as necessary to increase or experiment with the r2 score
#
# In addition to the above, I would create more tests with different metrics to see the performance of different configurations of the model.
